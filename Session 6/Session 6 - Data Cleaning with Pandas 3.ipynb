# %%
import pandas as pd

wind_data = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/opsd_germany_daily.csv',
                       index_col=0, parse_dates=True)
wind_data
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %%
wind_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4383 entries, 2006-01-01 to 2017-12-31
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Consumption  4383 non-null   float64
#  1   Wind         2920 non-null   float64
#  2   Solar        2188 non-null   float64
#  3   Wind+Solar   2187 non-null   float64
# dtypes: float64(4)
# memory usage: 171.2 KB

# %%
wind_data['Year'] = wind_data.index.year
wind_data['Month'] = wind_data.index.month
wind_data['Day'] = wind_data.index.day

# %%
wind_data
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month  Day
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN  2006      1    1
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006      1    2
# 2006-01-03   1442.53300      NaN     NaN         NaN  2006      1    3
# 2006-01-04   1457.21700      NaN     NaN         NaN  2006      1    4
# 2006-01-05   1477.13100      NaN     NaN         NaN  2006      1    5
# ...                 ...      ...     ...         ...   ...    ...  ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017     12   27
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017     12   28
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017     12   29
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017     12   30
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017     12   31
#
# [4383 rows x 7 columns]

# %%
wind_data.loc['2017-12-27']
# Out:
# Consumption    1263.94091
# Wind            394.50700
# Solar            16.53000
# Wind+Solar      411.03700
# Year           2017.00000
# Month            12.00000
# Day              27.00000
# Name: 2017-12-27 00:00:00, dtype: float64

# %%
wind_data.loc['2017-12-27':'2017-12-30']
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month  Day
# Date
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017     12   27
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017     12   28
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017     12   29
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017     12   30

# %%
wind_data.loc['2017-12']
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month  Day
# Date
# 2017-12-01   1592.96187   52.323  19.266      71.589  2017     12    1
# 2017-12-02   1391.85405  126.274  16.459     142.733  2017     12    2
# 2017-12-03   1330.26226  387.490  12.411     399.901  2017     12    3
# 2017-12-04   1620.97758  479.798  10.747     490.545  2017     12    4
# 2017-12-05   1643.72307  611.488  10.953     622.441  2017     12    5
# 2017-12-06   1639.08265  632.501   7.618     640.119  2017     12    6
# 2017-12-07   1628.47979  743.725  42.994     786.719  2017     12    7
# 2017-12-08   1618.05658  652.830  20.504     673.334  2017     12    8
# 2017-12-09   1415.34531  712.317  12.344     724.661  2017     12    9
# 2017-12-10   1318.10964  622.944   9.922     632.866  2017     12   10
# 2017-12-11   1614.15862  415.109   5.669     420.778  2017     12   11
# 2017-12-12   1647.36346  590.101  13.250     603.351  2017     12   12
# ...

# %%
wind_data.loc['2017']
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month  Day
# Date
# 2017-01-01   1130.41300  307.125  35.291     342.416  2017      1    1
# 2017-01-02   1441.05200  295.099  12.479     307.578  2017      1    2
# 2017-01-03   1529.99000  666.173   9.351     675.524  2017      1    3
# 2017-01-04   1553.08300  686.578  12.814     699.392  2017      1    4
# 2017-01-05   1547.23800  261.758  20.797     282.555  2017      1    5
# ...                 ...      ...     ...         ...   ...    ...  ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017     12   27
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017     12   28
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017     12   29
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017     12   30
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017     12   31
#
# [365 rows x 7 columns]

# %%
wind_data['Consumption'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
wind_data['Consumption'].plot(marker='.', linestyle='None')
# Out:
# <AxesSubplot:xlabel='Date'>
